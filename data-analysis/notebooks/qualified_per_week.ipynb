# %%
import pandas as pd

# %%
df = pd.read_csv('../data/percentage_quality_candidates.csv', sep=',')

# %%
lines = df.plot.line()

# %%
 lines = df.plot.line(x='week', y='percentage_quality_candidates')
